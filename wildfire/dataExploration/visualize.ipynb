# %%
# !pip install xarray
# !pip install pandas
# !pip install seaborn
# !pip install xarray
# Out:
# Collecting xarray
#   Using cached xarray-2023.5.0-py3-none-any.whl (994 kB)
# Requirement already satisfied: numpy>=1.21 in /opt/conda/lib/python3.9/site-packages (from xarray) (1.22.0)
# Collecting pandas>=1.4
#   Downloading pandas-2.0.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.4 MB)
#      |████████████████████████████████| 12.4 MB 19.7 MB/s
# Collecting packaging>=21.3
#   Using cached packaging-23.1-py3-none-any.whl (48 kB)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.9/site-packages (from pandas>=1.4->xarray) (2021.1)
# Collecting tzdata>=2022.1
#   Using cached tzdata-2023.3-py2.py3-none-any.whl (341 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.9/site-packages (from pandas>=1.4->xarray) (2.8.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas>=1.4->xarray) (1.16.0)
# Installing collected packages: tzdata, pandas, packaging, xarray
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.0
#     Uninstalling packaging-21.0:
#       Successfully uninstalled packaging-21.0
# Successfully installed packaging-23.1 pandas-2.0.2 tzdata-2023.3 xarray-2023.5.0
# Requirement already satisfied: pandas in /opt/conda/lib/python3.9/site-packages (2.0.2)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.9/site-packages (from pandas) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.9/site-packages (from pandas) (2021.1)
# Requirement already satisfied: numpy>=1.20.3 in /opt/conda/lib/python3.9/site-packages (from pandas) (1.22.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Collecting seaborn
#   Using cached seaborn-0.12.2-py3-none-any.whl (293 kB)
# Collecting matplotlib!=3.6.1,>=3.1
#   Using cached matplotlib-3.7.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
# Requirement already satisfied: pandas>=0.25 in /opt/conda/lib/python3.9/site-packages (from seaborn) (2.0.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /opt/conda/lib/python3.9/site-packages (from seaborn) (1.22.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.1)
# Collecting contourpy>=1.0.1
#   Using cached contourpy-1.0.7-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (299 kB)
# Collecting cycler>=0.10
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting importlib-resources>=3.2.0
#   Using cached importlib_resources-5.12.0-py3-none-any.whl (36 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Collecting kiwisolver>=1.0.1
#   Using cached kiwisolver-1.4.4-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
# Collecting fonttools>=4.22.0
#   Using cached fonttools-4.39.4-py3-none-any.whl (1.0 MB)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.4.7)
# Collecting pillow>=6.2.0
#   Using cached Pillow-9.5.0-cp39-cp39-manylinux_2_28_x86_64.whl (3.4 MB)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.9/site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.9/site-packages (from pandas>=0.25->seaborn) (2021.1)
# Requirement already satisfied: zipp>=3.1.0 in /opt/conda/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.1->seaborn) (3.5.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Installing collected packages: pillow, kiwisolver, importlib-resources, fonttools, cycler, contourpy, matplotlib, seaborn
# Successfully installed contourpy-1.0.7 cycler-0.11.0 fonttools-4.39.4 importlib-resources-5.12.0 kiwisolver-1.4.4 matplotlib-3.7.1 pillow-9.5.0 seaborn-0.12.2
# Requirement already satisfied: xarray in /opt/conda/lib/python3.9/site-packages (2023.5.0)
# Requirement already satisfied: pandas>=1.4 in /opt/conda/lib/python3.9/site-packages (from xarray) (2.0.2)
# Requirement already satisfied: numpy>=1.21 in /opt/conda/lib/python3.9/site-packages (from xarray) (1.22.0)
# Requirement already satisfied: packaging>=21.3 in /opt/conda/lib/python3.9/site-packages (from xarray) (23.1)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.9/site-packages (from pandas>=1.4->xarray) (2021.1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.9/site-packages (from pandas>=1.4->xarray) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.9/site-packages (from pandas>=1.4->xarray) (2.8.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas>=1.4->xarray) (1.16.0)

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('datasets/BAOverZero.csv')

# %%
df
# Out:
#         Unnamed: 0                 time  latitude  longitude    BurntArea  \
# 0            46499  2001-01-01 12:00:00    46.125     39.375    42.870000
# 1            47816  2001-01-01 12:00:00    45.625     38.125   150.050000
# 2            49119  2001-01-01 12:00:00    45.125     38.125   235.799990
# 3            49120  2001-01-01 12:00:00    45.125     38.375    21.439999
# 4            49121  2001-01-01 12:00:00    45.125     38.625  1307.590000
# ...            ...                  ...       ...        ...          ...
# 392958    14621218  2015-11-01 12:00:00   -37.125    -65.375   128.620000
# 392959    14621834  2015-11-01 12:00:00   -38.625    -64.625  1307.590000
# 392960    14622140  2015-11-01 12:00:00   -39.875    -63.625    42.879997
# 392961    14622143  2015-11-01 12:00:00   -39.875    -62.875   192.920000
# 392962    14622187  2015-11-01 12:00:00   -40.125    -64.625   471.590000
#
#             NDVI        DCM        LST      WIND    PRECIP        SSR
# 0       0.188361  257.93750  13951.500  2.416967  0.554007   2.610314
# 1       0.316412  415.66666  14061.000  2.617575  1.439043   3.095765
# 2       0.427016  531.37500  14117.250  2.163381  0.493541   3.522644
# 3       0.483403  542.56250  14124.750  2.133087  0.384019   3.553634
# 4       0.460326  531.43750  14173.750  2.133811  0.315218   3.600156
# ...          ...        ...        ...       ...       ...        ...
# 392958  0.428356  333.43490  15387.833  4.191670  3.216185  22.791370
# 392959  0.432225  383.46667  15413.625  4.071478  0.574636  23.979626
# 392960  0.297886  429.25260  15472.000  4.315669  2.768572  24.379108
# 392961  0.428787  395.67188  15159.429  4.267161  1.669484  23.866087
# 392962  0.329665  463.75000  15286.833  4.709396  1.435953  24.678688
#
# [392963 rows x 11 columns]

# %%
df2=df.loc[df['BurntArea']>0]

# %%
df2.loc[:,'BurntArea'].mean()
# Out:
# 1360.7981698028314

# %%
df2.to_csv("BAOverZero.csv")

# %%
df3=df2.drop(columns=['time'])

# %%
df3
# Out:
#         Unnamed: 0  latitude  longitude    BurntArea      NDVI        DCM  \
# 0            46499    46.125     39.375    42.870000  0.188361  257.93750
# 1            47816    45.625     38.125   150.050000  0.316412  415.66666
# 2            49119    45.125     38.125   235.799990  0.427016  531.37500
# 3            49120    45.125     38.375    21.439999  0.483403  542.56250
# 4            49121    45.125     38.625  1307.590000  0.460326  531.43750
# ...            ...       ...        ...          ...       ...        ...
# 392958    14621218   -37.125    -65.375   128.620000  0.428356  333.43490
# 392959    14621834   -38.625    -64.625  1307.590000  0.432225  383.46667
# 392960    14622140   -39.875    -63.625    42.879997  0.297886  429.25260
# 392961    14622143   -39.875    -62.875   192.920000  0.428787  395.67188
# 392962    14622187   -40.125    -64.625   471.590000  0.329665  463.75000
#
#               LST      WIND    PRECIP        SSR
# 0       13951.500  2.416967  0.554007   2.610314
# 1       14061.000  2.617575  1.439043   3.095765
# 2       14117.250  2.163381  0.493541   3.522644
# 3       14124.750  2.133087  0.384019   3.553634
# 4       14173.750  2.133811  0.315218   3.600156
# ...           ...       ...       ...        ...
# 392958  15387.833  4.191670  3.216185  22.791370
# 392959  15413.625  4.071478  0.574636  23.979626
# 392960  15472.000  4.315669  2.768572  24.379108
# 392961  15159.429  4.267161  1.669484  23.866087
# 392962  15286.833  4.709396  1.435953  24.678688
#
# [392963 rows x 10 columns]

# %%
corr=df3.corr()

# %%
cmap=sns.diverging_palette(230,20,as_cmap=True)
sns.heatmap(corr,cmap=cmap)
# Out:
# <Axes: >

# %%
df4=df3.loc[(df['LST']>15900)&(df['WIND']>4.55)]

# %%
df4.loc[:,'BurntArea'].mean()
# Out:
# 2332.2353769752795

# %%
corr2=df4.corr()
cmap=sns.diverging_palette(230,20,as_cmap=True)
sns.heatmap(corr2,cmap=cmap)
# Out:
# <Axes: >
